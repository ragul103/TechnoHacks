# %% [markdown]
# Peform Data Cleaning
# Clean a Dataset by Removing Missing values and Outliers

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('Employee Sample Data.csv', encoding='latin1')
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 0    Research & Development  Female      Black   55    4/8/2016     $141,604
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# ...

# %%
df_cleaned = df.dropna()
df_cleaned
# Out:
#        EEID        Full Name             Job Title       Department  \
# 0    E02387      Emily Davis            Sr. Manger               IT
# 7    E04332      Luke Martin               Analyst          Finance
# 14   E03496      Robert Yang           Sr. Analyst       Accounting
# 40   E01754         Owen Lam  Sr. Business Partner  Human Resources
# 61   E00502  Natalia Salazar           Sr. Analyst       Accounting
# ..      ...              ...                   ...              ...
# 963  E03305     Cooper Jiang            Analyst II       Accounting
# 982  E03247      Aaliyah Mai        Vice President               IT
# 983  E02703      Austin Vang               Manager        Marketing
# 991  E03430      Leo Herrera  Sr. Business Partner  Human Resources
# 996  E01909     Lillian Khan               Analyst          Finance
#
#               Business Unit  Gender Ethnicity  Age   Hire Date Annual Salary  \
# ...

# %%
def remove_outliers_zscore(data, threshold=3):
    z_scores = np.abs((data - data.mean()) / data.std())
    return data[(z_scores < threshold).all(axis=1)]

# %%
numerical_columns = df_cleaned.select_dtypes(include=[np.number])
numerical_columns
# Out:
#      Age
# 0     55
# 7     25
# 14    31
# 40    30
# 61    44
# ..   ...
# 963   49
# 982   57
# 983   49
# 991   48
# 996   44
#
# [85 rows x 1 columns]

# %%
df_cleaned[numerical_columns.columns] = remove_outliers_zscore(numerical_columns)
df_cleaned[numerical_columns.columns]
# Out:
# C:\Users\rglra\AppData\Local\Temp\ipykernel_14888\3036390889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned[numerical_columns.columns] = remove_outliers_zscore(numerical_columns)
#      Age
# 0     55
# 7     25
# 14    31
# 40    30
# 61    44
# ..   ...
# 963   49
# 982   57
# 983   49
# 991   48
# 996   44
#
# [85 rows x 1 columns]

# %%
df_cleaned.to_csv('cleaned_dataset.csv', index=False)

# %%
df_cleaned
# Out:
#        EEID        Full Name             Job Title       Department  \
# 0    E02387      Emily Davis            Sr. Manger               IT
# 7    E04332      Luke Martin               Analyst          Finance
# 14   E03496      Robert Yang           Sr. Analyst       Accounting
# 40   E01754         Owen Lam  Sr. Business Partner  Human Resources
# 61   E00502  Natalia Salazar           Sr. Analyst       Accounting
# ..      ...              ...                   ...              ...
# 963  E03305     Cooper Jiang            Analyst II       Accounting
# 982  E03247      Aaliyah Mai        Vice President               IT
# 983  E02703      Austin Vang               Manager        Marketing
# 991  E03430      Leo Herrera  Sr. Business Partner  Human Resources
# 996  E01909     Lillian Khan               Analyst          Finance
#
#               Business Unit  Gender Ethnicity  Age   Hire Date Annual Salary  \
# ...
